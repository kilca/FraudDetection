# %%
import numpy as np
from scipy.sparse import csr_matrix,csc_matrix, lil_matrix
from scipy.io import savemat, loadmat
import pandas as pd

# %% [markdown]
# # Amazon_mp3

# %%
df = pd.read_csv('data_out/amazon_mp3.csv')

# %%
df.head(10)
# Out:
#    num  id  productId  standardName             productName  \
# 0    1   0          0           NaN  Rio PMP 300 MP3 Player
# 1    2   0          0           NaN  Rio PMP 300 MP3 Player
# 2    3   0          0           NaN  Rio PMP 300 MP3 Player
# 3    4   0          0           NaN  Rio PMP 300 MP3 Player
# 4    5   0          0           NaN  Rio PMP 300 MP3 Player
# 5    6   0          0           NaN  Rio PMP 300 MP3 Player
# 6    7   0          0           NaN  Rio PMP 300 MP3 Player
# 7    8   0          0           NaN  Rio PMP 300 MP3 Player
# 8    9   0          0           NaN  Rio PMP 300 MP3 Player
# 9   10   0          0           NaN  Rio PMP 300 MP3 Player
#
#                                                title  \
# 0  Great for people with internet not for people ...
# 1            WOW! THE BEST THING TO HAPPEN TO MUSIC!
# 2  The first MP3 Handheld available on the Consum...
# 3                Next Millenium Consumer Electronics
# ...

# %% [markdown]
# # Amazon-meta

# %% [markdown]
# Fichier trop long

# %% [markdown]
# # Amazon0302

# %%
mat = scipy.io.loadmat('data_out/data_amz.mat')

# %% [markdown]
# On affiche les 10 premiers valeurs

# %%
print(mat['M'])
# Out:
#   (1, 0)	1
#   (2, 0)	1
#   (0, 1)	1
#   (0, 2)	1
#   (1, 2)	1
#   (0, 3)	1
#   (0, 4)	1
#   (1, 4)	1
#   (0, 5)	1
#   (1, 5)	1
#   (6, 5)	1
#   (7, 5)	1
#   (5, 6)	1
#   (4, 7)	1
#   (5, 7)	1
#   (6, 7)	1
#   (5, 8)	1
#   (6, 8)	1
#   (7, 8)	1
#   (5, 9)	1
#   (6, 9)	1
#   (7, 9)	1
#   (5, 10)	1
#   (2, 11)	1
#   (2, 12)	1
#   (2, 13)	1
#   (8, 13)	1
#   (2, 14)	1
#   (1, 15)	1
#   (4, 16)	1
#   (4, 17)	1
#   (4, 18)	1
#   (4, 19)	1
#   (6, 20)	1
#   (8, 21)	1
#   (8, 22)	1
#   (8, 23)	1
#   (8, 24)	1
#   (7, 30)	1
#   (3, 63)	1
#   (3, 64)	1
#   (3, 65)	1
#   (3, 66)	1
#   (3, 67)	1
#   (7, 290)	1
